# %%
# %matplotlib
import geopandas as gpd
import glob
from itertools import tee
import networkx as nx
import pandas as pd
import numpy as np
from shapely.geometry import Point, Polygon, LineString
import matplotlib.pyplot as plt
import matplotlib
import json
import os
from collections import defaultdict
from shapely.geometry import Point, Polygon, LineString

#Roads = gpd.read_file("/Users/mac/Desktop/N-N_roads/N-N_Roads.shp")
df_line = gpd.read_file("/Users/mac/Google 云端硬盘/M_City_Shuttle/AA_Map/Trip/allTRIP/df_line.shp")
Buildings = gpd.read_file("/Users/mac/Desktop/N-N_buildings/N-N_Buildings.shp")
# Out:
# Using matplotlib backend: MacOSX

# %%
df_line.loc[857,:]
# Out:
#        FID                                           geometry
# 0        0  LINESTRING (276282.745669152 4685569.058503695...
# 1        1  LINESTRING (276282.745669152 4685569.058503695...
# 2        2  LINESTRING (276282.745669152 4685569.058503695...
# 3        3  LINESTRING (275915.8863654568 4685580.441264, ...
# 4        4  LINESTRING (276282.745669152 4685569.058503695...
# 5        5  LINESTRING (276385.5370933599 4685979.49195418...
# 6        6  LINESTRING (276172.4678323958 4686102.13656688...
# 7        7  LINESTRING (276282.745669152 4685569.058503695...
# 8        8  LINESTRING (276361.9571860341 4685813.46118393...
# 9        9  LINESTRING (275881.6410342745 4685697.07753422...
# 10      10  LINESTRING (276282.745669152 4685569.058503695...
# 11      11  LINESTRING (276385.5370933599 4685979.49195418...
# 12      12  LINESTRING (276282.745669152 4685569.058503695...
# 13      13  LINESTRING (276282.745669152 4685569.058503695...
# ...

# %%
df_line.loc[857,:]
# Out:
# FID                                                       857
# geometry    LINESTRING (276577.2746662971 4685842.89102640...
# Name: 857, dtype: object

# %%
df_line.loc[857,'geometry']

# %%
trip1 = df_line[df_line.FID == 2]
trip1.to_file('/Users/mac/Desktop/NC_trip.shp', driver='ESRI Shapefile')

# %%
trip2 = df_line[df_line.FID == 857]
trip2.to_file('/Users/mac/Desktop/NCRC_trip.shp', driver='ESRI Shapefile')

# %%
trip2
# Out:
#    FID                                           geometry
# 2    2  LINESTRING (276282.745669152 4685569.058503695...
